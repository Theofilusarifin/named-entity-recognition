# %% [markdown]
# ### Quickstart
#
# https://github.com/urchade/GLiNER

# %%
from gliner import GLiNER

# Load from save
model = GLiNER.from_pretrained("urchade/gliner_medium-v2.1")

# model.save_pretrained("urchade/gliner_medium-v2.1")

text = """
Cristiano Ronaldo dos Santos Aveiro (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu]; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for and captains both Saudi Pro League club Al Nassr and the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won five Ballon d'Or awards,[note 3] a record three UEFA Men's Player of the Year Awards, and four European Golden Shoes, the most by a European player. He has won 33 trophies in his career, including seven league titles, five UEFA Champions Leagues, the UEFA European Championship and the UEFA Nations League. Ronaldo holds the records for most appearances (183), goals (140) and assists (42) in the Champions League, goals in the European Championship (14), international goals (128) and international appearances (205). He is one of the few players to have made over 1,200 professional career appearances, the most by an outfield player, and has scored over 850 official senior career goals for club and country, making him the top goalscorer of all time.
"""

labels = ["person", "award", "date", "competitions", "teams"]

entities = model.predict_entities(text, labels)

for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# config.json not found in /home/theo/Documents/Github/named-entity-recognition/urchade/gliner_multi-v2.1
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Cristiano Ronaldo dos Santos Aveiro => person
# 5 February 1985 => date
# Portugal national team => teams
# Ballon d'Or awards => award
# UEFA Men's Player of the Year Awards => award
# European Golden Shoes => award
# UEFA Champions Leagues => competitions
# UEFA European Championship => competitions
# UEFA Nations League => competitions
# European Championship => competitions

# %% [markdown]
# ### Dataset Bahasa Testing

# %%
# Daftar kategori NER yang digunakan
ner_category = [
    "organisasi",
    "waktu",
    "business_metric",
    "lokasi"
]

# Dataset kalimat yang lebih kompleks
dataset = [
    "Perusahaan ABC melaporkan total revenue sebesar Rp2 triliun pada tahun fiskal 2023.",
    "Jumlah pengguna aktif bulanan aplikasi XYZ mencapai 5 juta orang pada Juli 2023.",
    "PT DEF mengalami churn rate sebesar 10% pada kuartal kedua 2023.",
    "Bank GHI mencatat net promoter score (NPS) sebesar 70 dalam survei pelanggan terbaru.",
    "Startup JKL meningkatkan customer acquisition cost (CAC) menjadi Rp500.000 per pelanggan pada semester pertama 2023.",
    "Perusahaan MNO meningkatkan customer lifetime value (CLV) menjadi Rp1 miliar pada akhir tahun 2022.",
    "Tingkat retensi pelanggan PT PQR mencapai 85% pada kuartal ketiga 2023.",
    "Perusahaan STU melaporkan gross profit margin sebesar 40% dalam laporan keuangan tahunan.",
    "Rasio utang terhadap ekuitas (debt-to-equity ratio) Bank VWX turun menjadi 1,5 pada Maret 2023.",
    "Perusahaan YZA mencapai market share sebesar 25% di pasar smartphone Indonesia.",
    "PT BCD mencatat return on investment (ROI) sebesar 15% setelah kampanye pemasaran digital.",
    "Jumlah transaksi harian di platform e-commerce EFG melebihi 100.000 pada Agustus 2023.",
    "Perusahaan HIJ berhasil meningkatkan conversion rate menjadi 3% pada website mereka.",
    "Startup KLM mencapai break-even point dalam waktu 18 bulan sejak peluncuran.",
    "PT NOP mencatat average revenue per user (ARPU) sebesar Rp200.000 pada tahun 2023."
]

# Hasil NER per kalimat
ner_result = [
    {
        # Kalimat 1
        "organisasi": ["Perusahaan ABC"],
        "business_metric": ["total revenue"],
        "waktu": ["tahun fiskal 2023"]
    },
    {
        # Kalimat 2
        "organisasi": ["aplikasi XYZ"],
        "business_metric": ["jumlah pengguna aktif bulanan"],
        "waktu": ["Juli 2023"]
    },
    {
        # Kalimat 3
        "organisasi": ["PT DEF"],
        "business_metric": ["churn rate"],
        "waktu": ["kuartal kedua 2023"]
    },
    {
        # Kalimat 4
        "organisasi": ["Bank GHI"],
        "business_metric": ["net promoter score", "NPS"],
    },
    {
        # Kalimat 5
        "organisasi": ["Startup JKL"],
        "business_metric": ["customer acquisition cost", "CAC"],
        "waktu": ["semester pertama 2023"]
    },
    {
        # Kalimat 6
        "organisasi": ["Perusahaan MNO"],
        "business_metric": ["customer lifetime value", "CLV"],
        "waktu": ["akhir tahun 2022"]
    },
    {
        # Kalimat 7
        "organisasi": ["PT PQR"],
        "business_metric": ["tingkat retensi pelanggan"],
        "waktu": ["kuartal ketiga 2023"]
    },
    {
        # Kalimat 8
        "organisasi": ["Perusahaan STU"],
        "business_metric": ["gross profit margin"],
    },
    {
        # Kalimat 9
        "organisasi": ["Bank VWX"],
        "business_metric": ["rasio utang terhadap ekuitas", "debt-to-equity ratio"],
        "waktu": ["Maret 2023"]
    },
    {
        # Kalimat 10
        "organisasi": ["Perusahaan YZA"],
        "business_metric": ["market share"],
        "lokasi": ["pasar smartphone Indonesia"]
    },
    {
        # Kalimat 11
        "organisasi": ["PT BCD"],
        "business_metric": ["return on investment", "ROI"],
    },
    {
        # Kalimat 12
        "organisasi": ["platform e-commerce EFG"],
        "business_metric": ["jumlah transaksi harian"],
        "waktu": ["Agustus 2023"]
    },
    {
        # Kalimat 13
        "organisasi": ["Perusahaan HIJ"],
        "business_metric": ["conversion rate"],
    },
    {
        # Kalimat 14
        "organisasi": ["Startup KLM"],
        "business_metric": ["break-even point"],
        "waktu": ["dalam waktu 18 bulan sejak peluncuran"]
    },
    {
        # Kalimat 15
        "organisasi": ["PT NOP"],
        "business_metric": ["average revenue per user", "ARPU"],
        "waktu": ["tahun 2023"]
    }
]

# %%
from gliner import GLiNER

# Load from save
model = GLiNER.from_pretrained("urchade/gliner_multi-v2.1")

for i in range(len(dataset)):
    entities = model.predict_entities(dataset[i], ner_category)
    prediction_result = {}
    for entity in entities:
        if entity["label"] not in prediction_result:
            prediction_result[entity["label"]] = [entity["text"]]
        else:
            prediction_result[entity["label"]] = prediction_result[entity["label"]].append(entity["text"])
    
    print(f"--------------{i}--------------")
    print("pred: ", prediction_result)
    print("truth: ", ner_result[i])
    print()
# Out:
# config.json not found in /home/theo/Documents/Github/named-entity-recognition/urchade/gliner_multi-v2.1
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# --------------0--------------
# pred:  {'organisasi': ['Perusahaan ABC'], 'waktu': ['tahun fiskal 2023']}
# truth:  {'organisasi': ['Perusahaan ABC'], 'business_metric': ['total revenue'], 'waktu': ['tahun fiskal 2023']}
#
# --------------1--------------
# pred:  {'organisasi': ['XYZ'], 'waktu': ['Juli 2023']}
# truth:  {'organisasi': ['aplikasi XYZ'], 'business_metric': ['jumlah pengguna aktif bulanan'], 'waktu': ['Juli 2023']}
#
# --------------2--------------
# pred:  {'organisasi': ['PT DEF'], 'business_metric': None, 'waktu': ['kuartal kedua 2023']}
# truth:  {'organisasi': ['PT DEF'], 'business_metric': ['churn rate'], 'waktu': ['kuartal kedua 2023']}
#
# --------------3--------------
# ...

# %%
from gliner import GLiNER

# Load from save
model = GLiNER.from_pretrained("urchade/gliner_medium-v2.1")

for i in range(len(dataset)):
    entities = model.predict_entities(dataset[i], ner_category)
    prediction_result = {}
    for entity in entities:
        if entity["label"] not in prediction_result:
            prediction_result[entity["label"]] = [entity["text"]]
        else:
            prediction_result[entity["label"]] = prediction_result[entity["label"]].append(entity["text"])
    
    print(f"--------------{i}--------------")
    print("pred: ", prediction_result)
    print("truth: ", ner_result[i])
    print()
# Out:
# config.json not found in /home/theo/Documents/Github/named-entity-recognition/urchade/gliner_medium-v2.1
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# --------------0--------------
# pred:  {'organisasi': ['ABC'], 'waktu': ['tahun fiskal 2023']}
# truth:  {'organisasi': ['Perusahaan ABC'], 'business_metric': ['total revenue'], 'waktu': ['tahun fiskal 2023']}
#
# --------------1--------------
# pred:  {'organisasi': ['XYZ'], 'waktu': ['Juli 2023']}
# truth:  {'organisasi': ['aplikasi XYZ'], 'business_metric': ['jumlah pengguna aktif bulanan'], 'waktu': ['Juli 2023']}
#
# --------------2--------------
# pred:  {'organisasi': ['PT DEF'], 'business_metric': ['churn rate'], 'waktu': ['2023']}
# truth:  {'organisasi': ['PT DEF'], 'business_metric': ['churn rate'], 'waktu': ['kuartal kedua 2023']}
#
# --------------3--------------
# pred:  {'organisasi': ['Bank GHI'], 'business_metric': None}
# ...
